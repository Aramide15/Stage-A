# %%
import pandas as pd
import numpy as np
data1 = pd.read_excel(r'C:\Users\Doris\Downloads\FoodBalanceSheets_E_Africa_NOFLAG.xlsx')

# %%
data1.groupby(['Y2014']).sum() #to get the sum of the column Y2014
# Out:
#            Area Code  Item Code  Element Code     Y2015     Y2016     Y2017  \
# Y2014
# -1796.0          159       2657          5072     -73.0     -12.0       0.0
# -1631.0          159       2924          5072       6.0     -77.0    -689.0
# -849.0           266       5444         10340   -1118.0   -1119.0   -1200.0
# -838.0           184       2907          5072    -827.0    -679.0    -538.0
# -685.0           143       2905          5072    3418.0   -3225.0     689.0
# ...              ...        ...           ...       ...       ...       ...
#  90425.0          59       2501           511   92443.0   94447.0   96443.0
#  98094.0         238       2501           511  100835.0  103603.0  106400.0
#  108756.0        159       2907          5301  110798.0  116483.0  112625.0
#  109593.0        159       2907          5511  111663.0  119330.0  117702.0
#  176405.0        159       2501           511  181137.0  185960.0  190873.0
#
#               Y2018
# Y2014
# ...

# %%
#Qs 11: What is the total sum of Animal Fat produced in 2014 and 2017 respectively? Answer is 209460.54 and 269617.53
data1.groupby(['Item']).sum()
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %%
#Qs 12:What is the mean and standard deviation across the whole dataset for the year 2015 to 3 decimal places?
data1.groupby(['Y2015']).min()
# Out:
#            Area Code          Area  Item Code                      Item  \
# Y2015
# -3161.0          202  South Africa       2905  Cereals - Excluding Beer
# -2152.0          202  South Africa       2514        Maize and products
# -1284.0          276         Sudan       2905  Cereals - Excluding Beer
# -907.0           251        Zambia       2905  Cereals - Excluding Beer
# -887.0           276         Sudan       2518      Sorghum and products
# ...              ...           ...        ...                       ...
#  92443.0          59         Egypt       2501                Population
#  100835.0        238      Ethiopia       2501                Population
#  110798.0        159       Nigeria       2907             Starchy Roots
#  111663.0        159       Nigeria       2907             Starchy Roots
#  181137.0        159       Nigeria       2501                Population
#
#            Element Code                        Element          Unit  \
# Y2015
# ...

# %%
# QS 13: What is the total number and percentage of missing data in 2016 to 2 decimal places? asnwer is 1535 and 2.52
data1.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
#Qs 14: Which year had the highest correlation with ‘Element Code’? Answer is Y2017
data1.groupby("Element Code").max()
# Out:
#               Area Code                   Area  Item Code        Item  \
# Element Code
# 511                 276               Zimbabwe       2501  Population
# 645                 276               Zimbabwe       2961        Yams
# 664                 276               Zimbabwe       2961        Yams
# 674                 276               Zimbabwe       2961        Yams
# 684                 276               Zimbabwe       2961        Yams
# 5072                276               Zimbabwe       2961        Yams
# 5123                276               Zimbabwe       2949        Yams
# 5131                276               Zimbabwe       2948        Wine
# 5142                276               Zimbabwe       2961        Yams
# 5154                276               Zimbabwe       2961        Yams
# 5170                276               Zimbabwe       2949        Yams
# 5171                193  Sao Tome and Principe       2949        Yams
# ...

# %%
# Qs 15:What year has the highest sum of Import Quantity? Answer is Y2016
data1.groupby("Element").max()
# Out:
#                                         Area Code                   Area  \
# Element
# Domestic supply quantity                      276               Zimbabwe
# Export Quantity                               276               Zimbabwe
# Fat supply quantity (g/capita/day)            276               Zimbabwe
# Feed                                          276               Zimbabwe
# Food                                          276               Zimbabwe
# Food supply (kcal/capita/day)                 276               Zimbabwe
# Food supply quantity (kg/capita/yr)           276               Zimbabwe
# Import Quantity                               276               Zimbabwe
# Losses                                        276               Zimbabwe
# Other uses (non-food)                         276               Zimbabwe
# Processing                                    276               Zimbabwe
# Production                                    276               Zimbabwe
# ...

# %%
import pandas as pd
import numpy as np
data1 = pd.read_excel(r'C:\Users\Doris\Downloads\FoodBalanceSheets_E_Africa_NOFLAG.xlsx')
#Qs 16: What is the total number of the sum of Production in 2014?
data1.groupby([len(data1)]).sum()

# %%
import pandas as pd
import numpy as np
data1 = pd.read_excel(r'C:\Users\Doris\Downloads\FoodBalanceSheets_E_Africa_NOFLAG.xlsx')
# Qs 17:Which of these elements had the highest sum in 2018? answer is "Domestic supply quantity"
# Qs 18:Which of these elements had the 3rd lowest sum in 2018? answer is "Protein supply quantity (g/capita/day)"
data1.groupby(["Element"]).sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
# Qs 19:What is the total Import Quantity in Algeria in 2018?
data1.groupby(["Area","Element"]).sum()
# Out:
#                                                  Area Code  Item Code  \
# Area     Element
# Algeria  Domestic supply quantity                      464     311204
#          Export Quantity                               392     264011
#          Fat supply quantity (g/capita/day)            432     291489
#          Feed                                           88      58967
#          Food                                          420     282744
# ...                                                    ...        ...
# Zimbabwe Protein supply quantity (g/capita/day)      20453     304589
#          Residuals                                   18824     277476
#          Seed                                         3439      50560
#          Stock Variation                             17195     254157
#          Total Population - Both sexes                 181       2501
#
#                                                  Element Code     Y2014  \
# Area     Element
# ...

# %%
#Qs 20:What is the total number of unique countries in the dataset? Answer is 49.
data1.groupby('Area')['Area'].count()
# Out:
# Area
# Algeria                        1313
# Angola                         1424
# Benin                          1285
# Botswana                       1378
# Burkina Faso                   1409
# Cabo Verde                     1260
# Cameroon                       1460
# Central African Republic       1344
# Chad                           1343
# Comoros                          45
# Congo                          1413
# Côte d'Ivoire                  1467
# Djibouti                       1095
# Egypt                          1488
# Eswatini                       1284
# Ethiopia                       1447
# Ethiopia PDR                     39
# Gabon                          1245
# Gambia                         1168
# Ghana                          1354
# Guinea                         1410
# Guinea-Bissau                  1128
# Kenya                          1560
# Lesotho                        1150
# Liberia                        1206
# Madagascar                     1439
# ...
